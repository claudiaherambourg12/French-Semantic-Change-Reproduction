# %%
import os

cleaned_dir = '../Datasets/decade_cleaned'
total_tokens = 0
vocab = set()

for filename in os.listdir(cleaned_dir):
    if filename.endswith(".txt"):
        with open(os.path.join(cleaned_dir, filename), 'r', encoding='utf-8') as f:
            tokens = f.read().split()
            total_tokens += len(tokens)
            vocab.update(tokens)

print(f"Total Tokens: {total_tokens:,}")
print(f"Unique Words (Vocab): {len(vocab):,}")
# Out:
# Total Tokens: 466,610,966
# Unique Words (Vocab): 306,084
